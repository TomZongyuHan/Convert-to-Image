# %%
from google.colab import drive
import os
import numpy as np
import pandas as pd
from IPython.display import display

# %%
drive.mount("/content/drive")

# Please put your project folder in google drive root path of My Drive
path = "/content/drive/My Drive/27-1"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['originalDatasets',
#  'README.md',
#  'main.py',
#  'installDependencies.py',
#  'methods',
#  'cnnModels',
#  'results',
#  'test.py',
#  '.ipynb_checkpoints',
#  'test_colab.ipynb',
#  'showTestResults.ipynb']

# %%
testResults = np.load('results/accuracies/testResults.npy')
#testResults = np.reshape(testResults, (2,-1)).transpose()

df = pd.DataFrame(testResults)
#df.columns = ['test accuracy','train accuracy']
df.columns = ['train accuracy', 'test accuracy', 'test f1 score']

# %%
print(df.shape)
df.head(14)
# Out:
# (360, 2)
#     test accuracy  train accuracy
# 0        0.923077         0.92126
# 1        0.000000         0.00000
# 2        0.000000         0.00000
# 3        0.000000         0.00000
# 4        0.000000         0.00000
# 5        0.000000         0.00000
# 6        0.000000         0.00000
# 7        0.000000         0.00000
# 8        0.000000         0.00000
# 9        0.000000         0.00000
# 10       0.000000         0.00000
# 11       0.000000         0.00000
# 12       0.000000         0.00000
# 13       0.000000         0.00000
